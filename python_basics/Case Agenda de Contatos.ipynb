# %%
import json


agenda = []


def salvar_agenda():
    with open("agenda.json", "w") as arquivo:
        json.dump(agenda,arquivo)
    print("Agenda foi salva com sucesso!")


def carregar_agenda():
    try:
        with open("agenda.json", "r") as arquivo:
            agenda = json.load(arquivo)
        print("Agenda carregada com sucesso!")
        return agenda
    except:
        print("\nNenhuma agenda foi encontrada! Começando uma nova agenda.")
        return []

def adicionar_contato(nome, telefone, email):
    contato = {
        "nome": nome,
        "telefone": telefone,
        "email": email
    }
    agenda.append(contato)
    print(f"Contato {nome} adicionado!")

def exibir_contatos():
    print("\nContatos na agenda:")
    for contato in agenda:
        print("Nome:", contato['nome'])
        print("Telefone:", contato['telefone'])
        print("Email:", contato['email'])

def editar_contato():
    nome= input("Digite o nome do contato que deseja editar:")
    for contato in agenda:
        if contato["nome"] == nome:
            contato["telefone"] = input("Digite o novo número de telefone:")
            contato["email"] = input("Digite o novo email:")
            print("\nContato atualizado!")
            break
        else:
            print("Contato não encontrado!\n")

def remover_contato():
    nome= input("Digite o nome do contato que deseja remover:")
    for contato in agenda:
        if contato['nome'] == nome:
            agenda.remove(contato)
            print("Contato removido.\n")
            return
    print("Contato não encontrado!\n")

agenda = carregar_agenda()
    
while True:
    print("\n--menu da agenda--")
    print("1. Adicionar contato")
    print("2. Exibir agenda")
    print("3. Editar contato.")
    print("4. Remover contato.")
    print("5. Salvar agenda")
    print("6. Sair.")

    opcao = input("Digite a opção desejada: ")

    if opcao == "1":
        nome = input("Digite o nome: ")
        telefone = input("Digite o telefone: ")
        email = input("Digite o email: ")
        adicionar_contato(nome, telefone, email)

    elif opcao == "2":
        exibir_contatos()

    elif opcao == "3":
        editar_contato()

    elif opcao == "4":
        remover_contato()

    elif opcao == "5":
        salvar_agenda()

    elif opcao == "6":
        print("Encerrando...")
        break

    else:
        print("Opção inválida!")
# Out:
# Nenhuma agenda foi encontrada! Começando uma nova agenda.
#
# --menu da agenda--
# 1. Adicionar contato
# 2. Exibir agenda
# 3. Editar contato.
# 4. Remover contato.
# 5. Salvar agenda
# 6. Sair.
# Digite a opção desejada:  1
# Digite o nome:  Luiz
# Digite o telefone:  +5511993446928
# Digite o email:  luizhnr@gmail.com
# Contato Luiz adicionado!
#
# --menu da agenda--
# 1. Adicionar contato
# 2. Exibir agenda
# 3. Editar contato.
# 4. Remover contato.
# 5. Salvar agenda
# 6. Sair.
# Digite a opção desejada:  1
# Digite o nome:  Francisca
# Digite o telefone:  +5515992834
# Digite o email:  fran@gmail.com
# Contato Francisca adicionado!
#
# --menu da agenda--
# 1. Adicionar contato
# 2. Exibir agenda
# 3. Editar contato.
# 4. Remover contato.
# 5. Salvar agenda
# 6. Sair.
# Digite a opção desejada:  2
# Contatos na agenda:
# Nome: Luiz
# Telefone: +5511993446928
# Email: luizhnr@gmail.com
# Nome: Francisca
# Telefone: +5515992834
# Email: fran@gmail.com
#
# --menu da agenda--
# 1. Adicionar contato
# 2. Exibir agenda
# 3. Editar contato.
# 4. Remover contato.
# 5. Salvar agenda
# 6. Sair.
