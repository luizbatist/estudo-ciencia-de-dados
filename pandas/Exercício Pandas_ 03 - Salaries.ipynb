# %%
import pandas as pd

# %%
df = pd.read_csv("Salaries.csv", low_memory = False)

# %%
df.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %% [markdown]
# ### 📌 EXERCÍCIO 1 — Limpeza mínima e verificação
# Quero que você converta a coluna BasePay para número de forma correta e segura.
# Tarefa:
#
# Converta a coluna BasePay para tipo numérico usando pd.to_numeric com errors="coerce".
#
# Depois, mostre o tipo final dessa coluna usando df["BasePay"].dtype.
#
# Seu resultado deve ser um dtype igual a float64.

# %%
df["BasePay"] = pd.to_numeric(df["BasePay"], errors = "coerce")

# %%
df["BasePay"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### 📌 EXERCÍCIO 2 — Identificar nulos e interpretar corretamente
# Tarefa:
#
# Mostre quantos valores nulos existem na coluna BasePay usando:
#
# df["BasePay"].isnull().sum()
#
#
# Interprete o resultado em uma frase simples, dizendo por que existem nulos após a conversão e se isso é esperado ou preocupante dentro dessa base.

# %%
df["BasePay"].isnull().sum()
# Out:
# np.int64(609)

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df["BasePay"]
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %% [markdown]
# ### 📌 EXERCÍCIO 3 — Encontrar o maior salário base (BasePay) e a pessoa correspondente
# Tarefa:
#
# 1. Encontre o maior valor da coluna BasePay.
# Dica: use .max().
#
# 2. Encontre a linha completa da pessoa que possui esse maior salário base.
# Dica: use:
#
# *df.loc[df["BasePay"].idxmax()]*
#
#
# ou, se preferir o estilo tradicional:
#
# *df[df["BasePay"] == df["BasePay"].max()]*
#
#
# (Os dois funcionam; escolha um.)
#
# 3. Interprete: o nome da pessoa e quanto ela ganha de BasePay.
#
# Envie para mim:
#
# * O valor máximo encontrado
#
# * A linha ou informações da pessoa
#
# * Uma frase interpretando o resultado
#
# Exemplo da frase esperada:
#
# “A pessoa com maior BasePay é X, com salário Y.”

# %%
df["BasePay"].max()
# Out:
# 319275.01

# %%
df.loc[df["BasePay"].idxmax()]
# Out:
# Id                            72926
# EmployeeName         Gregory P Suhr
# JobTitle            Chief of Police
# BasePay                   319275.01
# OvertimePay                     0.0
# OtherPay                   20007.06
# Benefits                   86533.21
# TotalPay                  339282.07
# TotalPayBenefits          425815.28
# Year                           2013
# Notes                           NaN
# Agency                San Francisco
# Status                          NaN
# Name: 72925, dtype: object

# %% [markdown]
# ### 📌 EXERCÍCIO 4 — Quem é a pessoa mais mal paga?
# 1. Encontre o menor valor de BasePay (mínimo).
# Dica: df["BasePay"].min()
# 2. Recupere a linha completa dessa pessoa.
# Dica:
#
# df.loc[df["BasePay"].idxmin()]
#
# 3.  Interprete:
#
# * Nome
#
# * Cargo
#
# * BasePay
#
# * Se o salário parece legítimo ou se é provavelmente um problema de dados

# %%
df["BasePay"].min()
# Out:
# -166.01

# %%
df.loc[df["BasePay"].idxmin()]
# Out:
# Id                           72833
# EmployeeName        Irwin Sidharta
# JobTitle              Junior Clerk
# BasePay                    -166.01
# OvertimePay                 249.02
# OtherPay                       0.0
# Benefits                      6.56
# TotalPay                     83.01
# TotalPayBenefits             89.57
# Year                          2012
# Notes                          NaN
# Agency               San Francisco
# Status                         NaN
# Name: 72832, dtype: object

# %% [markdown]
# ### 📌 EXERCÍCIO 5 — Quantos títulos de trabalho (Job Titles) existem?
# 1. Conte quantos cargos diferentes existem na coluna JobTitle.
# Dica:
#
# df["JobTitle"].nunique()
#
# 2. Conte quantos funcionários existem por cargo.
# Dica:
#
# df["JobTitle"].value_counts()
#
# 3. Me diga:
#
# * Quantos cargos únicos existem
#
# * Qual é o cargo mais comum
#
# * Quantas pessoas ocupam esse cargo

# %%
df["JobTitle"].nunique()
# Out:
# 2159

# %%
df["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                      7036
# Special Nurse                         4389
# Registered Nurse                      3736
# Public Svc Aide-Public Works          2518
# Police Officer 3                      2421
#                                       ...
# Light Rail Vehicle Equip Eng             1
# Civil Case Settlmnt Specialist           1
# ADMINISTRATOR, SFGH MEDICAL CENTER       1
# CHIEF OF POLICE                          1
# Special Assistant 8                      1
# Name: count, Length: 2159, dtype: int64

# %% [markdown]
# ### 📌 EXERCÍCIO 6 — Quantas pessoas têm a palavra “chief” no cargo?
# Esse exercício treina filtro por string, algo essencial em análises reais.
#
# 1. Filtrar todas as linhas onde JobTitle contém a palavra “chief”, ignorando maiúsculas/minúsculas.
# Dica:
# df["JobTitle"].str.contains("chief", case=False, na=False)
#
# 2. Contar quantas pessoas possuem essa característica.
#
# 3. Me dizer:
#
# * Quantas pessoas têm “chief” no cargo
#
# * Se esse número te surpreendeu ou não — e por quê

# %%
df["JobTitle"].str.contains("chief",case=False,na=False).sum()
# Out:
# np.int64(627)

# %% [markdown]
# ### 📌 EXERCÍCIO 7 — Qual é a média de TotalPayBenefits por ano?
# 1. Calcule a média anual da coluna TotalPayBenefits.
# Dica:
#
# df.groupby("Year")["TotalPayBenefits"].mean()
#
# 2. Interprete:
#
# Qual ano teve a maior média?
#
# A diferença entre os anos é grande ou pequena?

# %%
df.groupby("Year")["TotalPayBenefits"].mean()
# Out:
# Year
# 2011     71744.103871
# 2012    100553.229232
# 2013    101440.519714
# 2014    100250.918884
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### EXERCÍCIO 8 — Qual cargo teve a maior média de TotalPayBenefits?
# Agora você vai juntar tudo:
#
# * groupby
# * ordenação
# * interpretação de cargo
#
# 1. Calcule a média de TotalPayBenefits para cada cargo:
# 2. Ordene do maior para o menor:
# 3. Pegue o top 1 (maior média salarial)
# 4. Interprete:
#
# * Qual é o cargo mais bem pago em média?
#
# * O valor faz sentido ou parece distorção?
#
# * Você acha que é um cargo com poucos registros?

# %%
df.groupby("JobTitle")["TotalPayBenefits"].mean().sort_values(ascending=False)
# Out:
# JobTitle
# Chief Investment Officer                          436224.360000
# Chief of Police                                   411732.266667
# Chief, Fire Department                            408865.326667
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    399211.275000
# Gen Mgr, Public Trnsp Dept                        380696.440000
#                                                       ...
# BOARD/COMMISSION MEMBER, GROUP III                   638.787879
# BdComm Mbr, Grp2,M=$25/Mtg                           475.047742
# BOARD/COMMISSION MEMBER, GROUP II                    296.511628
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN              149.510000
# Not provided                                           0.000000
# Name: TotalPayBenefits, Length: 2159, dtype: float64

# %%
df["JobTitle"].value_counts()["Chief Investment Officer"]
# Out:
# np.int64(1)

# %% [markdown]
# ### EXERCÍCIO 9 — Quais cargos têm média salarial acima de 200.000 dólares?
# 1. Calcule
# df.groupby("JobTitle")["TotalPayBenefits"].mean()
# 2. Filtre apenas cargos com média acima de 200.000.
# 3. Liste:
#
# Nome do cargo
#
# Média salarial
#
# 4. Interprete:
#
# Esses cargos parecem legítimos ou são outliers?
#
# São cargos com muitos ou poucos registros?

# %%
df.groupby("JobTitle")["TotalPayBenefits"].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ACCOUNTANT                                        47429.268000
# ACCOUNTANT INTERN                                 29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                       80266.370000
# ACUPUNCTURIST                                     67594.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             52705.880385
# X-Ray Laboratory Aide                             69521.123200
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# Youth Comm Advisor                                60118.550000
# ZOO CURATOR                                       66686.560000
# Name: TotalPayBenefits, Length: 2159, dtype: float64

# %%
media_por_cargo = df.groupby("JobTitle")["TotalPayBenefits"].mean()

# %%
media_acima_200k = media_por_cargo[media_por_cargo > 200000]

# %%
media_acima_200k.sort_values(ascending=False)
# Out:
# JobTitle
# Chief Investment Officer                            436224.360000
# Chief of Police                                     411732.266667
# Chief, Fire Department                              408865.326667
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY      399211.275000
# Gen Mgr, Public Trnsp Dept                          380696.440000
#                                                         ...
# Assistant Inspector 2                               201184.724000
# DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG    200921.488000
# Supervising Pharmacist                              200822.078095
# Chief Dep Adlt Prob Of (SFERS)                      200616.833333
# Transmission Line Supervisor 1                      200389.980000
# Name: TotalPayBenefits, Length: 114, dtype: float64

# %%
media_acima_200k
# Out:
# JobTitle
# ADMINISTRATOR, SFGH MEDICAL CENTER                  257124.440000
# ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)    203427.850000
# ASSISTANT DEPUTY CHIEF II                           228724.506000
# ASSISTANT MEDICAL EXAMINER                          212793.172000
# Adm, SFGH Medical Center                            347079.706667
#                                                         ...
# Supervising Physician Spec                          244458.533269
# Transmission Line Supervisor 1                      200389.980000
# Treasurer                                           231371.396667
# Trnst Power Line Wrk Sprv 2                         214776.440000
# Wire Rope Cable Maint Sprv                          242118.323333
# Name: TotalPayBenefits, Length: 114, dtype: float64

# %%
media_acima_200k.count()
# Out:
# np.int64(114)

# %%
df["JobTitle"].value_counts()["ADMINISTRATOR, SFGH MEDICAL CENTER"]
# Out:
# np.int64(1)

# %% [markdown]
# ### Exercício 10 — Quantas pessoas trabalham exatamente no cargo “Transit Operator” e qual é o salário médio delas?

# %%
df["JobTitle"].value_counts()["Transit Operator"]
# Out:
# np.int64(7036)

# %%
df[df["JobTitle"] == "Transit Operator"]["TotalPayBenefits"].mean()
# Out:
# np.float64(92066.74444997158)
