# %%
import numpy as np
import pandas as pd

# %%
minha_lista = [10, 20, 30]
minha_tupla = [10, 20, 30]
meu_array = np.array([10, 20, 30])
meu_dict = {1: 10, 2: 20, 3: 30}

# %%
#criando uma series a partir de uma lista
pd.Series(data=minha_lista)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = minha_lista, index=["primeiro", "segundo", "terceiro"])  #COLOCANDO INDEX
# Out:
# primeiro    10
# segundo     20
# terceiro    30
# dtype: int64

# %%
minha_series = pd.Series(data = minha_lista, index=["primeiro", "segundo", "terceiro"])  #COLOCANDO INDEX

# %%
minha_series["primeiro"]
# Out:
# np.int64(10)

# %%
minha_series[["primeiro", "terceiro"]]
# Out:
# primeiro    10
# terceiro    30
# dtype: int64

# %%
meu_dict_novo = {"primeiro": 10, "segundo": 20, "terceiro": 30}
pd.Series(meu_dict_novo)
# Out:
# primeiro    10
# segundo     20
# terceiro    30
# dtype: int64

# %%
pd.Series(["a", "b", "c"])
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
